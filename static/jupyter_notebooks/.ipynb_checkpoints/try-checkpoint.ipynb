# %%
import sys
sys.path.append('STARTUP\django_jupyter.py')
from django_jupyter import init_django

init_django('PWD')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# c:\Users\angie\OneDrive\Documents\GitHub\SMARTS\STARTUP\try.ipynb Cell 1 line 5
#       <a href='vscode-notebook-cell:/c%3A/Users/angie/OneDrive/Documents/GitHub/SMARTS/STARTUP/try.ipynb#W6sZmlsZQ%3D%3D?line=1'>2</a> sys.path.append('STARTUP\django_jupyter.py')
#       <a href='vscode-notebook-cell:/c%3A/Users/angie/OneDrive/Documents/GitHub/SMARTS/STARTUP/try.ipynb#W6sZmlsZQ%3D%3D?line=2'>3</a> from django_jupyter import init_django
# ----> <a href='vscode-notebook-cell:/c%3A/Users/angie/OneDrive/Documents/GitHub/SMARTS/STARTUP/try.ipynb#W6sZmlsZQ%3D%3D?line=4'>5</a> init_django('STARTUP')
#
# File c:\Users\angie\OneDrive\Documents\GitHub\SMARTS\STARTUP\django_jupyter.py:13, in init_django(STARTUP)
#      12 def init_django(STARTUP=None):
# ---> 13     os.chdir(STARTUP)
#      14     STARTUP = STARTUP or os.environ.get('DJANGO_PROJECT') or None
#      15     if STARTUP is None:
#
# FileNotFoundError: [WinError 2] The system cannot find the file specified: 'STARTUP'

# %%
from django.contrib.auth import get_user_model

# %%
import os

os.environ.setdefault("DJANGO_SETTINGS_MODULE", "STARTUP.settings")
# Out:
# 'STARTUP.settings'

# %% [markdown]
# User = get_user_model()

# %%
import sys
import pyrebase
sys.path.append('home\firebase_config.py')
from firebase_config import config



def print_nested_data(data, indent=0):
    for key, value in data.items():
        if isinstance(value, dict):
            print(" " * indent + f"Key: {key}:")
            print_nested_data(value, indent + 4)
        else:
            print(" " * indent + f"Key: {key}: {value}")

firebase=pyrebase.initialize_app(config)
authe = firebase.auth()
database=firebase.database()

#print (config)

registered_iot = f'IOT/'

all_iot = database.child(registered_iot).get()

if all_iot.val():
    all_iot_dict = all_iot.val()
    

def print_nested_dict(data, indent=0):
    for key, value in data.items():
        print(' ' * indent + f"{key}: ", end='')
        if isinstance(value, dict):
            print("{")
            print_nested_dict(value, indent + 4)
            print(' ' * indent + "}")
        else:
            print(value)

for column, values in all_iot_dict.items():
    print(f"Column: {column}")
    print_nested_dict(values)
    print("-------------")
# Out:
# Column: 12569852
# DATA: {
#     HUMID: {
#         Oct-06-2023: {
#             00:00: 80
#             00:02: 80
#             00:04: 80
#         }
#     }
#     TEMP: {
#         Oct-06-2023: {
#             00:00: 29
#             00:02: 29
#             00:04: 29
#         }
#     }
# }
# S1: {
#     CropDetails: {
#         cropName: Lettuce
#         dateRegistered: 2023-10-04
#         harvestStat: NOT YET
#         isUsingGreenhouse: True
#     }
#     SD: {
#         SML: 50
#     }
#     StaticData: {
#         SoilMoistureLvl: {
#             Oct-06-2023: {
#                 00:00: 50
#                 00:02: 50
#                 00:04: 50
#             }
#         }
#     }
#     WaterIrrigation: {
#         LastOn:
#         Switch: 0
#         WaterTemp: 40
#     }
# }
# S2:
# S3:
# STATIC: {
#     HUMID: 80
#     TEMP: 28
# }
# -------------
# Column: 15004526
# DATA: {
#     HUMID:
#     TEMP:
# }
# S1: {
#     CropDetails: {
#         cropDatePlanted: 2023-10-04
#         cropName: Lettuce
#         dateRegistered: 2023-10-04
#         harvestStat: NOT YET
#         isUsingGreenhouse: True
#     }
#     DATA: {
#         SOIL: {
#             Oct-04-2023: {
#                 13:50: 0
#                 13:52: 0
#             }
#             Oct-05-2023: {
#                 14:58: 0
#             }
#         }
#     }
#     SD: {
#         SML: 0
#     }
#     StaticData: {
#         SoilMoistureLvl: 0
#     }
#     WaterIrrigation: {
#         LastOn: Oct-05-2023 15:02
#         Switch: 0
#         WaterTemp: 40
#     }
# }
# S2: {
#     DATA: {
#         SOIL: {
#             Oct-04-2023: {
#                 13:50: 170
#                 13:52: 176
#             }
#             Oct-05-2023: {
#                 14:58: 138
#             }
#         }
#     }
#     SD: {
#         SML: 53
#     }
#     StaticData: {
#         SoilMoistureLvl: 142
#     }
#     WaterIrrigation: {
#         Switch: 0
#     }
# }
# S3: {
#     DATA: {
#         SOIL: {
#             Oct-04-2023: {
#                 13:50: 116
#                 13:52: 135
#             }
#             Oct-05-2023: {
#                 14:58: 115
#             }
#         }
#     }
#     SD: {
#         SML: 16
#     }
#     StaticData: {
#         SoilMoistureLvl: 153
#     }
#     WaterIrrigation: {
#         LastOn: Oct-05-2023 15:02
#         Switch: 0
#     }
# }
# STATIC: {
#     HUMID: 4
#     TEMP: 30
# }
# -------------
# Column: 90020223
# S1: {
#     CropDetails: {
#         cropDatePlanted: 2022-09-24
#         cropName: Lettuce
#         dateRegistered: 2023-09-26
#         isUsingGreenhouse: True
#     }
#     StaticData: {
#         SoilMoistureLvl:
#     }
#     WaterIrrigation: {
#         LastOn:
#         Switch:
#         WaterTemp:
#     }
# }
# S2: {
#     CropDetails: {
#         cropDatePlanted: 2023-09-25
#         cropName: Petchay
#         dateRegistered: 2023-09-27
#         harvestStat: NOT YET
#         isUsingGreenhouse: True
#     }
#     StaticData: {
#         SoilMoistureLvl:
#     }
#     WaterIrrigation: {
#         LastOn:
#         Switch:
#         WaterTemp:
#     }
# }
# S3:
# -------------
# Column: 15004526S1
# STATIC: {
#     TEMP: 32.0
# }
# -------------
